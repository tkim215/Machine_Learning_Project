# %%
import cv2
import numpy as np

# %%
imageFile = "C:/Users/kimta/Introduction to Machine Learning/raw_data/flag_pic.png"

img1 = cv2.imread(imageFile)

print(img1.shape)
print(img1)
# Out:
# (170, 255, 3)
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
img2 = cv2.imread(imageFile,0)
print(img2.shape)
print(img2)
# Out:
# (170, 255)
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
from skimage import data, io, filters

edges = filters.sobel(img2)
io.imshow(edges)
io.show()

# %%
from PIL import Image
image_scaled = Image.open("C:/Users/kimta/Introduction to Machine Learning/raw_data/flag_pic.png")
tiny_flag = image_scaled.resize((100, 100))
tiny_flag
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1B6397642E0>

# %%
img2_scaled2=cv2.resize(img2, dsize=(100, 100))

# %%
img2_rev = img2_scaled2.reshape(-1,100*100)
np.mean(img2_rev)
# Out:
# 214.3305
